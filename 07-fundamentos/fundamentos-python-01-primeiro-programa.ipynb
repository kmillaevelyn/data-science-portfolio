# %% [markdown]
# <a href="https://colab.research.google.com/github/kmillaevelyn/data-science-portfolio/blob/main/07-fundamentos/fundamentos-python-01-primeiro-programa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Conheço esse código!")
# Out:
# Conheço esse código!

# %%
x = 5

# %%
y = 15

# %%
soma = x + y

# %%
print ("O resultado de x + y, é:", soma)
# Out:
# O resultado de x + y, é: 20

# %%
idade = 62

# %%
if idade < 18:
  print("Menor de Idade")
  elif idade >= 18 and idade < 60:
  print("Adulto")
  else:
    print("Idoso")
# Out:
#   File "<ipython-input-20-eb7a15bb44e5>", line 3
#     elif idade >= 18 and idade < 60:
#     ^
# SyntaxError: invalid syntax

# %%
# Out:
#   File "<ipython-input-17-b6f62b578ea5>", line 1
#     elif idade >= 18 and idade < 60:
#     ^
# SyntaxError: invalid syntax

# %%
idade = 20

# %%
if idade < 18:
  print("Menor de Idade")
  elif idade >= 18 and idade <60:
    print("Adulto")
    else:
      print("Idoso")
# Out:
#   File "<ipython-input-24-b726029e46f7>", line 3
#     elif idade >= 18 and idade <60:
#     ^
# SyntaxError: invalid syntax
